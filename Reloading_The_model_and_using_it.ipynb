# %%
from ultralytics import YOLO

# Load the model
model = YOLO('best.pt')

# Run prediction on the image
results = model.predict(source='paper77.jpg', save=True)
# Out:
# image 1/1 C:\An_Extra_drive\Python Project\paper77.jpg: 480x640 1 paper, 2064.7ms
# Speed: 30.0ms preprocess, 2064.7ms inference, 46.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to C:\Users\PMYLS\runs\detect\predict30

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the YOLO-processed image
img = Image.open('C:/Users/PMYLS/runs/detect/predict30/paper77.jpg')  # Update with the correct path
plt.imshow(img)
plt.show()
